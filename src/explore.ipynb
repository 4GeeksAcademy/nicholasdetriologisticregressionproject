# %% [markdown]
# # Explore here

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Your code here
DATABASE_URL="https://raw.githubusercontent.com/4GeeksAcademy/logistic-regression-project-tutorial/main/bank-marketing-campaign-data.csv"

#train_data = pd.read_csv(DATABASE_URL)
#test_data = pd.read_csv(DATABASE_URL)
#test_survived_data = pd.read_csv(DATABASE_URL)
#test_data["Survived"] = test_survived_data["Survived"]

###

total_data = pd.read_csv(DATABASE_URL, delimiter=";")
total_data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
total_data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
total_data.shape
# Out:
# (41188, 21)

# %%
total_data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
total_data.iloc[1]
# Out:
# age                        57
# job                  services
# marital               married
# education         high.school
# default               unknown
# housing                    no
# loan                       no
# contact             telephone
# month                     may
# day_of_week               mon
# duration                  149
# campaign                    1
# pdays                     999
# previous                    0
# poutcome          nonexistent
# emp.var.rate              1.1
# cons.price.idx         93.994
# cons.conf.idx           -36.4
# euribor3m               4.857
# nr.employed            5191.0
# y                          no
# Name: 1, dtype: object

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
total_data.isnull().sum(axis=0)
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
total_data['y'].value_counts(normalize=True)
# Out:
# y
# no     0.887346
# yes    0.112654
# Name: proportion, dtype: float64

# %%
total_data['marital'].value_counts()
# Out:
# marital
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64

# %%
total_data['job'].value_counts()
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %%
total_data['education'].value_counts()
# Out:
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64

# %%
# do you currently have credit (categorical)
total_data['default'].value_counts()
# Out:
# default
# no         32588
# unknown     8597
# yes            3
# Name: count, dtype: int64

# %%
# do you have a housing loan (categorical) 
total_data['housing'].value_counts()
# Out:
# housing
# yes        21576
# no         18622
# unknown      990
# Name: count, dtype: int64

# %%
# Do you have a personal loan? (categorical)
total_data['loan'].value_counts()
# Out:
# loan
# no         33950
# yes         6248
# unknown      990
# Name: count, dtype: int64

# %%
# Type of contact communication (categorical)
total_data['contact'].value_counts()
# Out:
# contact
# cellular     26144
# telephone    15044
# Name: count, dtype: int64

# %%
# Last month in which you have been contacted (categorical)
total_data['month'].value_counts()
# Out:
# month
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: count, dtype: int64

# %%
# Last day on which you have been contacted (categorical)
total_data['day_of_week'].value_counts()
# Out:
# day_of_week
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7827
# Name: count, dtype: int64

# %%
# Duration of previous contact in seconds (numeric)
total_data['duration'].value_counts()
# Out:
# duration
# 90      170
# 85      170
# 136     168
# 73      167
# 124     164
#        ...
# 1569      1
# 1053      1
# 1263      1
# 1169      1
# 1868      1
# Name: count, Length: 1544, dtype: int64

# %%
# Number of contacts made during this campaign to the customer (numeric)
total_data['campaign'].value_counts()
# Out:
# campaign
# 1     17642
# 2     10570
# 3      5341
# 4      2651
# 5      1599
# 6       979
# 7       629
# 8       400
# 9       283
# 10      225
# 11      177
# 12      125
# 13       92
# 14       69
# 17       58
# 16       51
# 15       51
# 18       33
# 20       30
# 19       26
# 21       24
# 22       17
# 23       16
# 24       15
# 27       11
# 29       10
# 28        8
# 26        8
# 25        8
# 31        7
# 30        7
# 35        5
# 32        4
# 33        4
# 34        3
# 42        2
# 40        2
# 43        2
# 56        1
# 39        1
# 41        1
# 37        1
# Name: count, dtype: int64

# %%
# Number of days that elapsed since the last campaign until the customer was contacted (numeric)
total_data['pdays'].value_counts()
# Out:
# pdays
# 999    39673
# 3        439
# 6        412
# 4        118
# 9         64
# 2         61
# 7         60
# 12        58
# 10        52
# 5         46
# 13        36
# 11        28
# 1         26
# 15        24
# 14        20
# 8         18
# 0         15
# 16        11
# 17         8
# 18         7
# 22         3
# 19         3
# 21         2
# 25         1
# 26         1
# 27         1
# 20         1
# Name: count, dtype: int64

# %%
# Number of contacts made during the previous campaign to the customer (numeric)
total_data['previous'].value_counts()
# Out:
# previous
# 0    35563
# 1     4561
# 2      754
# 3      216
# 4       70
# 5       18
# 6        5
# 7        1
# Name: count, dtype: int64

# %%
# Result of the previous marketing campaign (categorical)
total_data['poutcome'].value_counts()
# Out:
# poutcome
# nonexistent    35563
# failure         4252
# success         1373
# Name: count, dtype: int64

# %%
# Employment variation rate. Quarterly indicator (numeric)
total_data['emp.var.rate'].value_counts()
# Out:
# emp.var.rate
#  1.4    16234
# -1.8     9184
#  1.1     7763
# -0.1     3683
# -2.9     1663
# -3.4     1071
# -1.7      773
# -1.1      635
# -3.0      172
# -0.2       10
# Name: count, dtype: int64

# %%
# Consumer price index. Monthly indicator (numeric)
total_data['cons.price.idx'].value_counts()
# Out:
# cons.price.idx
# 93.994    7763
# 93.918    6685
# 92.893    5794
# 93.444    5175
# 94.465    4374
# 93.200    3616
# 93.075    2458
# 92.201     770
# 92.963     715
# 92.431     447
# 92.649     357
# 94.215     311
# 94.199     303
# 92.843     282
# 92.379     267
# 93.369     264
# 94.027     233
# 94.055     229
# 93.876     212
# 94.601     204
# 92.469     178
# 93.749     174
# 92.713     172
# 94.767     128
# 93.798      67
# 92.756      10
# Name: count, dtype: int64

# %%
# Consumer price index. Monthly indicator (numeric)
total_data['cons.conf.idx'].value_counts()
# Out:
# cons.conf.idx
# -36.4    7763
# -42.7    6685
# -46.2    5794
# -36.1    5175
# -41.8    4374
# -42.0    3616
# -47.1    2458
# -31.4     770
# -40.8     715
# -26.9     447
# -30.1     357
# -40.3     311
# -37.5     303
# -50.0     282
# -29.8     267
# -34.8     264
# -38.3     233
# -39.8     229
# -40.0     212
# -49.5     204
# -33.6     178
# -34.6     174
# -33.0     172
# -50.8     128
# -40.4      67
# -45.9      10
# Name: count, dtype: int64

# %%
#EURIBOR 3-month rate. Daily indicator (numeric)
total_data['euribor3m'].value_counts()
# Out:
# euribor3m
# 4.857    2868
# 4.962    2613
# 4.963    2487
# 4.961    1902
# 4.856    1210
#          ...
# 3.853       1
# 3.901       1
# 0.969       1
# 0.956       1
# 3.669       1
# Name: count, Length: 316, dtype: int64

# %%
#Number of employees. Quarterly indicator (numeric)
total_data['nr.employed'].value_counts()
# Out:
# nr.employed
# 5228.1    16234
# 5099.1     8534
# 5191.0     7763
# 5195.8     3683
# 5076.2     1663
# 5017.5     1071
# 4991.6      773
# 5008.7      650
# 4963.6      635
# 5023.5      172
# 5176.3       10
# Name: count, dtype: int64

# %%
total_data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
total_data.duplicated()#.sum()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41183    False
# 41184    False
# 41185    False
# 41186    False
# 41187    False
# Length: 41188, dtype: bool

# %%
categorical_features = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', ]

fig, axis = plt.subplots(2, 5, figsize = (20, 10))

# Creating a multiple figure with histograms and box plots
sns.histplot(ax = axis[0, 0], data = total_data, x = "job")
sns.histplot(ax = axis[0, 1], data = total_data, x = "marital")
sns.histplot(ax = axis[0, 2], data = total_data, x = "education")
sns.histplot(ax = axis[0, 3], data = total_data, x = "default")
sns.histplot(ax = axis[0, 4], data = total_data, x = "housing")
sns.histplot(ax = axis[1, 0], data = total_data, x = "loan")
sns.histplot(ax = axis[1, 1], data = total_data, x = "contact")
sns.histplot(ax = axis[1, 2], data = total_data, x = "month")
sns.histplot(ax = axis[1, 3], data = total_data, x = "day_of_week")
sns.histplot(ax = axis[1, 4], data = total_data, x = "poutcome")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
numerical_features = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

fig, axis = plt.subplots(4, 2, figsize = (10, 10), gridspec_kw={'height_ratios': [6, 1, 6, 1]})

# Creating a multiple figure with histograms and box plots
sns.histplot(ax = axis[0, 0], data = total_data, x = "age").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = total_data, x = "age")
sns.histplot(ax = axis[0, 1], data = total_data, x = "duration").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = total_data, x = "duration")

sns.histplot(ax = axis[2, 0], data = total_data, x = "campaign").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 0], data = total_data, x = "campaign")
sns.histplot(ax = axis[2, 1], data = total_data, x = "pdays").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 1], data = total_data, x = "pdays")


# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# numerical_features = ['Age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

fig, axis = plt.subplots(4, 2, figsize = (10, 10), gridspec_kw={'height_ratios': [6, 1, 6, 1]})

# Creating a multiple figure with histograms and box plots
sns.histplot(ax = axis[0, 0], data = total_data, x = "previous").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = total_data, x = "previous")
sns.histplot(ax = axis[0, 1], data = total_data, x = "emp.var.rate").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = total_data, x = "emp.var.rate")

sns.histplot(ax = axis[2, 0], data = total_data, x = "cons.price.idx").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 0], data = total_data, x = "cons.price.idx")
sns.histplot(ax = axis[2, 1], data = total_data, x = "cons.conf.idx").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[3, 1], data = total_data, x = "cons.conf.idx")


# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# numerical_features = ['Age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

fig, axis = plt.subplots(2, 2, figsize = (10, 5), gridspec_kw={'height_ratios': [6, 1]})

# Creating a multiple figure with histograms and box plots
sns.histplot(ax = axis[0, 0], data = total_data, x = "euribor3m").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = total_data, x = "euribor3m")
sns.histplot(ax = axis[0, 1], data = total_data, x = "nr.employed").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = total_data, x = "nr.employed")




# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import numpy as np
plt.hist(np.log10(total_data['duration']+1), bins=25)
plt.xlabel('logp1 duration')
plt.show()

# %% [markdown]
# Analysis of Multivariate Variables
# After analyzing features one at a time, we can analyze them in relation to each other (muli-).
#
# We'll also split this up into
#
# 1.) Numerical-Numerical Analysis, and
#
# 2.) Categorical-Categorical Analysis
#
# 3.) Numerical-Categorial Analysis

# %%
numerical_features
# Out:
# ['age',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
fig, axis = plt.subplots(4, 2, figsize = (10, 15))

# Create a multiple scatter diagram
# sns.regplot(ax = axis[0, 0], data = total_data, x = "age", y = np.log10(total_data['duration']+1))
sns.regplot(ax = axis[0, 0], data = total_data, x = "age", y = "duration")
sns.heatmap(total_data[["age", "duration"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)

sns.regplot(ax = axis[0, 1], data = total_data, x = "campaign", y = "duration").set(ylabel=None)
sns.heatmap(total_data[["campaign", "duration"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])

sns.regplot(ax = axis[2, 0], data = total_data, x = "pdays", y = "duration").set(ylabel=None)
sns.heatmap(total_data[["pdays", "duration"]].corr(), annot = True, fmt = ".2f", ax = axis[3, 0], cbar=False)

sns.regplot(ax = axis[2, 1], data = total_data, x = "previous", y = "duration").set(ylabel=None)
sns.heatmap(total_data[["previous", "duration"]].corr(), annot = True, fmt = ".2f", ax = axis[3, 1])



# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# numerical_features = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

fig, axis = plt.subplots(4, 2, figsize = (10, 15))

# Create a multiple scatter diagram
# sns.regplot(ax = axis[0, 0], data = total_data, x = "age", y = np.log10(total_data['duration']+1))
sns.regplot(ax = axis[0, 0], data = total_data, x = "age", y = "cons.conf.idx")
sns.heatmap(total_data[["age", "cons.conf.idx"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 0], cbar = False)

sns.regplot(ax = axis[0, 1], data = total_data, x = "campaign", y = "cons.conf.idx").set(ylabel=None)
sns.heatmap(total_data[["campaign", "cons.conf.idx"]].corr(), annot = True, fmt = ".2f", ax = axis[1, 1])

sns.regplot(ax = axis[2, 0], data = total_data, x = "pdays", y = "cons.conf.idx").set(ylabel=None)
sns.heatmap(total_data[["pdays", "cons.conf.idx"]].corr(), annot = True, fmt = ".2f", ax = axis[3, 0], cbar=False)

sns.regplot(ax = axis[2, 1], data = total_data, x = "previous", y = "cons.conf.idx").set(ylabel=None)
sns.heatmap(total_data[["previous", "cons.conf.idx"]].corr(), annot = True, fmt = ".2f", ax = axis[3, 1])



# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Warning! Pairplots can be slow!
sns.pairplot(data = total_data[numerical_features])

# %%
sns.heatmap(total_data[numerical_features].corr(), annot = True, fmt = ".2f")
# Out:
# <Axes: >

# %%
categorical_features
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
fig, axis = plt.subplots(1,3, figsize = (15, 5))

sns.countplot(ax = axis[0], data = total_data, x = "job", hue = "education")
sns.countplot(ax = axis[1], data = total_data, x = "default", hue = "housing").set(ylabel = None)
sns.countplot(ax = axis[2], data = total_data, x = "loan", hue = "poutcome").set(ylabel = None)

plt.tight_layout()

plt.show()

# %%
sns.barplot(data = total_data, x = "loan", y = "poutcome", hue = "job")
# Out:
# <Axes: xlabel='loan', ylabel='poutcome'>

# %%
sns.barplot(data = total_data, x = "loan", y = "poutcome", hue = "default")
# Out:
# <Axes: xlabel='loan', ylabel='poutcome'>

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

train_data = pd.read_csv(DATABASE_URL, delimiter=";")
test_data = pd.read_csv(DATABASE_URL, delimiter=";")

print("Train Data Columns")
print(train_data.columns)
print("*"*80)
print("Test Data Columns")
print(test_data.columns)
# Out:
# Train Data Columns
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')
# ********************************************************************************
# Test Data Columns
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

train_data = pd.read_csv(DATABASE_URL, delimiter=";")
test_data = pd.read_csv(DATABASE_URL, delimiter=";")

#print("Train Data Columns")
#print(train_data.columns)
#print("*"*80)
#print("Test Data Columns")
#print(test_data.columns)

columns_to_factorize = ['marital', 'education', 'default', 'housing', 'loan', 
                        'contact', 'month', 'day_of_week', 'poutcome', 'job']

X_train = train_data.drop(["y"], axis = 1)

# Factorize each column in the training set
factorized_columns_train = []
for column in columns_to_factorize:
    factorized_column, _ = pd.factorize(X_train[column])
    X_train[column + '_factorized'] = factorized_column
    factorized_columns_train.append(column + '_factorized')
    X_train.drop(column, axis=1, inplace=True)

X_train
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
y_train = pd.factorize(train_data["y"])[0]

X_test = test_data.drop(["y"], axis = 1)

# Factorize each column in the test set
factorized_columns_test = []
for column in columns_to_factorize:
    factorized_column, _ = pd.factorize(X_test[column])
    X_test[column + '_factorized'] = factorized_column
    factorized_columns_test.append(column + '_factorized')
    X_test.drop(column, axis=1, inplace=True)

y_test = pd.factorize(test_data["y"])[0]


# Initialize and train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate accuracy
base_accuracy = accuracy_score(y_test, y_pred)
base_accuracy
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9064290570068952

# %%
from sklearn.model_selection import GridSearchCV

# We define the parameters by hand that we want to adjust
hyperparams = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    "penalty": ["l1", "l2", "elasticnet", None],
    "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]
}

# We initialize the grid
grid = GridSearchCV(model, hyperparams, scoring = "accuracy", cv = 5)
grid
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                          'penalty': ['l1', 'l2', 'elasticnet', None],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']},
#              scoring='accuracy')

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

grid.fit(X_train, y_train)

print(f"Best hyperparameters: {grid.best_params_}")

#took 15 minutes to run
#/home/vscode/.local/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
 # alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
#/home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
 # ret = line_search_wolfe2(
#Best hyperparameters: {'C': 0.001, 'penalty': 'l1', 'solver': 'saga'}

# %%
model_grid = LogisticRegression(penalty = "l1", C = 0.001, solver = "saga")
model_grid.fit(X_train, y_train)
y_pred = model_grid.predict(X_test)

grid_accuracy = accuracy_score(y_test, y_pred)
grid_accuracy
# Out:
# 0.9061134310964358

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV

# We define the parameters we want to adjust
hyperparams = {
    "C": np.logspace(-4, 4, 20),
    "penalty": ["l1", "l2", "elasticnet", None],
    "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]
}

# We initialize the random search
random_search = RandomizedSearchCV(model, hyperparams, n_iter = 100, scoring = "accuracy", cv = 5, random_state = 42)
random_search
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(), n_iter=100,
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'penalty': ['l1', 'l2', 'elasticnet',
#                                                     None],
#                                         'solver': ['newton-cg', 'lbfgs',
#                                                    'liblinear', 'sag',
#                                                    'saga']},
#                    random_state=42, scoring='accuracy')

# %%
random_search.fit(X_train, y_train)

print(f"Best hyperparameters: {random_search.best_params_}")

#/home/vscode/.local/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#  alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
#/home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#  ret = line_search_wolfe2(
# Best hyperparameters: {'solver': 'saga', 'penalty': 'l2', 'C': 0.0001}
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/scipy/optimize/_linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/optimize.py:74: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# Best hyperparameters: {'solver': 'saga', 'penalty': 'l2', 'C': 0.0001}

# %%
model_random_search = LogisticRegression(penalty = "l2", C = 0.0001, solver = "saga")
model_random_search.fit(X_train, y_train)
y_pred = model_random_search.predict(X_test)

random_search_accuracy = accuracy_score(y_test, y_pred)
random_search_accuracy
# Out:
# 0.906259104593571

# %%
print("Base Accuracy")
print("0.9064290570068952")

print("*"*20)
print("Grid Accuracy")
print("0.9061134310964358")

print("*"*20)
print("Random Search Accuracy")
print("0.906259104593571")
# 
#random_search_accuracy
# Out:
# Base Accuracy
# 0.9064290570068952
# ********************
# Grid Accuracy
# 0.9061134310964358
# ********************
# Random Search Accuracy
# 0.906259104593571
