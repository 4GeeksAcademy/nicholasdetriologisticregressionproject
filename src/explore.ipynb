# %% [markdown]
# # Explore here

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Your code here
DATABASE_URL="https://raw.githubusercontent.com/4GeeksAcademy/logistic-regression-project-tutorial/main/bank-marketing-campaign-data.csv"

#train_data = pd.read_csv(DATABASE_URL)
#test_data = pd.read_csv(DATABASE_URL)
#test_survived_data = pd.read_csv(DATABASE_URL)
#test_data["Survived"] = test_survived_data["Survived"]

###

total_data = pd.read_csv(DATABASE_URL, delimiter=";")
total_data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
total_data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
total_data.shape
# Out:
# (41188, 21)

# %%
total_data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
total_data.iloc[1]
# Out:
# age                        57
# job                  services
# marital               married
# education         high.school
# default               unknown
# housing                    no
# loan                       no
# contact             telephone
# month                     may
# day_of_week               mon
# duration                  149
# campaign                    1
# pdays                     999
# previous                    0
# poutcome          nonexistent
# emp.var.rate              1.1
# cons.price.idx         93.994
# cons.conf.idx           -36.4
# euribor3m               4.857
# nr.employed            5191.0
# y                          no
# Name: 1, dtype: object

# %%
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
total_data.isnull().sum(axis=0)
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
total_data['y'].value_counts(normalize=True)
# Out:
# y
# no     0.887346
# yes    0.112654
# Name: proportion, dtype: float64

# %%
total_data['marital'].value_counts()
# Out:
# marital
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64

# %%
total_data['job'].value_counts()
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %%
# Level of education
total_data['education'].value_counts()
# Out:
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64

# %%
# do you currently have credit (categorical)
total_data['default'].value_counts()
# Out:
# default
# no         32588
# unknown     8597
# yes            3
# Name: count, dtype: int64

# %%
# do you have a housing loan (categorical) 
total_data['housing'].value_counts()
# Out:
# housing
# yes        21576
# no         18622
# unknown      990
# Name: count, dtype: int64

# %%
# Do you have a personal loan? (categorical)
total_data['loan'].value_counts()
# Out:
# loan
# no         33950
# yes         6248
# unknown      990
# Name: count, dtype: int64

# %%
# Type of contact communication (categorical)
total_data['contact'].value_counts()
# Out:
# contact
# cellular     26144
# telephone    15044
# Name: count, dtype: int64

# %%
# Last month in which you have been contacted (categorical)
total_data['month'].value_counts()
# Out:
# month
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: count, dtype: int64

# %%
# Last day on which you have been contacted (categorical)
total_data['day_of_week'].value_counts()
# Out:
# day_of_week
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7827
# Name: count, dtype: int64

# %%
# Duration of previous contact in seconds (numeric)
total_data['duration'].value_counts()
# Out:
# duration
# 90      170
# 85      170
# 136     168
# 73      167
# 124     164
#        ...
# 1569      1
# 1053      1
# 1263      1
# 1169      1
# 1868      1
# Name: count, Length: 1544, dtype: int64

# %%
# Number of contacts made during this campaign to the customer (numeric)
total_data['campaign'].value_counts()
# Out:
# campaign
# 1     17642
# 2     10570
# 3      5341
# 4      2651
# 5      1599
# 6       979
# 7       629
# 8       400
# 9       283
# 10      225
# 11      177
# 12      125
# 13       92
# 14       69
# 17       58
# 16       51
# 15       51
# 18       33
# 20       30
# 19       26
# 21       24
# 22       17
# 23       16
# 24       15
# 27       11
# 29       10
# 28        8
# 26        8
# 25        8
# 31        7
# 30        7
# 35        5
# 32        4
# 33        4
# 34        3
# 42        2
# 40        2
# 43        2
# 56        1
# 39        1
# 41        1
# 37        1
# Name: count, dtype: int64

# %%
# Number of days that elapsed since the last campaign until the customer was contacted (numeric)
total_data['pdays'].value_counts()
# Out:
# pdays
# 999    39673
# 3        439
# 6        412
# 4        118
# 9         64
# 2         61
# 7         60
# 12        58
# 10        52
# 5         46
# 13        36
# 11        28
# 1         26
# 15        24
# 14        20
# 8         18
# 0         15
# 16        11
# 17         8
# 18         7
# 22         3
# 19         3
# 21         2
# 25         1
# 26         1
# 27         1
# 20         1
# Name: count, dtype: int64

# %%
# Number of contacts made during the previous campaign to the customer (numeric)
total_data['previous'].value_counts()
# Out:
# previous
# 0    35563
# 1     4561
# 2      754
# 3      216
# 4       70
# 5       18
# 6        5
# 7        1
# Name: count, dtype: int64

# %%
# Result of the previous marketing campaign (categorical)
total_data['poutcome'].value_counts()
# Out:
# poutcome
# nonexistent    35563
# failure         4252
# success         1373
# Name: count, dtype: int64

# %%
Employment variation rate. Quarterly indicator (numeric)
total_data['emp.var.rate'].value_counts()
